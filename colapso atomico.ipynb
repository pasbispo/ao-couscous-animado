# %%
# %matplotlib nbagg

# %%
import matplotlib.pyplot as plt # matplotlib.pyplot= é a função para fazer gráfico; import = importando o a função para uso no python; as plt= é o nome que você deu a função, você pode chamar essa função do jeito que você quiser  
import numpy as np  # numpy é usar as funções numericas, ou seja, importar as funções numericas. ( a busca é no próprio python, ou você pode definir as suas próprias funções)

# %%
h=6.62607004e-34
hc = h/(2*np.pi)
c=299.792458 
e2 = (1.6e-19)**2
e4 = e2*e2
eps0 = 8.85e-12
m = 9.11e-31
a_0 = 4*np.pi*eps0*hc*hc/(m*e2)
delta = e4/(12*np.pi*eps0**2*c**3*m**2)

def r(t):
    return np.power(1-t,1./3.)

def theta(L,t):
    return((a_0*L/(beta*m))*(1-r(t)))

def x(L,t):
    return(r(t)*np.cos(theta(L,t)))

def y(L,t):
    return(r(t)*np.sin(theta(L,t)))

# %%
#a_0*L/(beta*m)

# %%
#1-r(1)

# %%
#theta(L,1)

# %%
#print(a_0**3/(3*beta))

# %%
T = np.linspace(0,1,100)

# %%
#theta(L,0)

# %%
#r(T)

# %%
L = 50*beta*m/a_0
#print(L)
plt.plot(x(L,T),y(L,T),)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# # $$x = r \cos\theta$$
# # $$y = r \sin\theta$$

# %% [markdown]
# # $$r(t)=\left(a^3_0 - 3\beta t\right)^{1/3}$$

# %% [markdown]
# # $$L=a_0v_0$$

# %% [markdown]
# # $$\theta(L,t)=\frac{L}{m\beta}\left(a_0 - \left(a^3_0 - 3\beta t\right)^{1/3}\right)$$

# %%
#?np.linspace

# %%
#3*beta/a_0**3*1

# %%
#?np.sqrt

# %%
#print(theta(a_0*v*m,T))
#plt.ylim(-1,1)
#plt.xlim(-1,1)

# %%
#v = np.sqrt(2*10/(0.5/c))

#print(r(0))
