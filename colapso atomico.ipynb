# %%
#Esta simulação é uma adaptação de um exemplo do matplotilib.

# %%
# %matplotlib nbagg

# %%
import matplotlib.pyplot as plt   
import numpy as np

# %%
h=6.62607004e-34
hc = h/(2*np.pi)
c=299.792458 
e2 = (1.6e-19)**2
e4 = e2*e2
eps0 = 8.85e-12
m = 9.11e-31
a_0 = 4*np.pi*eps0*hc*hc/(m*e2)
beta = e4/(12*np.pi*eps0**2*c**3*m**2)


def r(t):
    return np.power(1-t,1./3.)

def theta(L,t):
    return((a_0*L/(beta*m))*(1-r(t)))

def x(L,t):
    return(r(t)*np.cos(theta(L,t)))

def y(L,t):
    return(r(t)*np.sin(theta(L,t)))

def vx(L,t):
    return

def vy(L,t):
    return
    
def v2(L,t):
    return np.sqrt(vx(L,t)*vx(L,t)+vy(L,t)*vy(L,t))

# %%
T = np.linspace(0,1,100000)

# %%
L = 300*beta*m/a_0
print(L)
plt.plot(x(L,T),y(L,T),'-')
plt.plot(0,0,'o')
# Out:
# 5.115121326547371e-20
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# # $$x = r \cos\theta$$
# # $$y = r \sin\theta$$

# %% [markdown]
# # $$r(t)=\left(a^3_0 - 3\beta t\right)^{1/3}$$

# %% [markdown]
# # $$L=a_0v_0$$

# %% [markdown]
# # $$\theta(L,t)=\frac{L}{m\beta}\left(a_0 - \left(a^3_0 - 3\beta t\right)^{1/3}\right)$$
